# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
import seaborn as sns
#import package

# %%
#Read Dataset
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
#Shape of the dataset
df_train.shape
# Out:
# (38312, 19)

# %%
df_train.head()
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# ...

# %%
df_test.isnull().sum() #remove null value
# Out:
# EmployeeNo                               0
# Division                                 0
# Qualification                          730
# Gender                                   0
# Channel_of_Recruitment                   0
# Trainings_Attended                       0
# Year_of_birth                            0
# Last_performance_score                   0
# Year_of_recruitment                      0
# Targets_met                              0
# Previous_Award                           0
# Training_score_average                   0
# State_Of_Origin                          0
# Foreign_schooled                         0
# Marital_Status                           0
# Past_Disciplinary_Action                 0
# Previous_IntraDepartmental_Movement      0
# No_of_previous_employers                 0
# dtype: int64

# %%
#drop null value
df_train.dropna(axis = 0, inplace = True)
df_test = df_test.fillna('No_Degree')

# %%
df_train.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
del df_train['Previous_IntraDepartmental_Movement']

# %%
del df_test['Previous_IntraDepartmental_Movement']

# %%
#del df_train['No_of_previous_employers']

# %%
#del df_test['No_of_previous_employers']

# %%
df_train['Age'] = 2019 - df_train['Year_of_birth']

# %%
df_test['Age'] = 2019 - df_test['Year_of_birth']

# %%
 del df_test['Year_of_birth']

# %%
del df_train['Year_of_birth']

# %%
#del df_train['Past_Disciplinary_Action']

# %%
#del df_test['Past_Disciplinary_Action']

# %%
del df_train['State_Of_Origin']

# %%
del df_test['State_Of_Origin']

# %%
df_train['Years_of_recruitment'] = 2019 - df_train['Year_of_recruitment']

# %%
df_test['Years_of_recruitment'] = 2019 - df_test['Year_of_recruitment']

# %%
del df_train['Year_of_recruitment']

# %%
del df_test['Year_of_recruitment']

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
df_test['Qualification'] = labelencoder.fit_transform(df_test['Qualification'])
df_test['Division'] = labelencoder.fit_transform(df_test['Division'])
df_test['Gender'] = labelencoder.fit_transform(df_test['Gender'])
df_test['Channel_of_Recruitment'] = labelencoder.fit_transform(df_test['Channel_of_Recruitment'])
df_test['Marital_Status'] = labelencoder.fit_transform(df_test['Marital_Status'])
df_test['Foreign_schooled'] = labelencoder.fit_transform(df_test['Foreign_schooled'])

# %%
df_test['Past_Disciplinary_Action'] = labelencoder.fit_transform(df_test['Past_Disciplinary_Action'])
df_test['No_of_previous_employers'] = labelencoder.fit_transform(df_test['No_of_previous_employers'])

# %%
df_train['Qualification'] = labelencoder.fit_transform(df_train['Qualification'])
df_train['Division'] = labelencoder.fit_transform(df_train['Division'])
df_train['Gender'] = labelencoder.fit_transform(df_train['Gender'])
df_train['Channel_of_Recruitment'] = labelencoder.fit_transform(df_train['Channel_of_Recruitment'])
df_train['Marital_Status'] = labelencoder.fit_transform(df_train['Marital_Status'])
df_train['Foreign_schooled'] = labelencoder.fit_transform(df_train['Foreign_schooled'])

# %%
df_train['Past_Disciplinary_Action'] = labelencoder.fit_transform(df_train['Past_Disciplinary_Action'])
df_train['No_of_previous_employers'] = labelencoder.fit_transform(df_train['No_of_previous_employers'])

# %%
df_train['Last_performance_score'] = labelencoder.fit_transform(df_train['Last_performance_score'])
df_train['Years_of_recruitment'] = labelencoder.fit_transform(df_train['Years_of_recruitment'])

# %%
df_test['Last_performance_score'] = labelencoder.fit_transform(df_test['Last_performance_score'])
df_test['Years_of_recruitment'] =  labelencoder.fit_transform(df_test['Years_of_recruitment'])
df_test['Training_score_average'] = labelencoder.fit_transform(df_test['Training_score_average'])

# %%
df_train['Training_score_average'] = labelencoder.fit_transform(df_train['Training_score_average'])

# %%
df_train['Training_score'] = pd.cut(df_train['Training_score_average'], 3, labels=["bad", "medium", "good"])

# %%
df_train['Training_scores'] = labelencoder.fit_transform(df_train['Training_score'])

# %%
df_test['Training_score'] = pd.cut(df_test['Training_score_average'], 3, labels=["bad", "medium", "good"])

# %%
df_test['Training_scores'] = labelencoder.fit_transform(df_test['Training_score'])

# %%
df_train['Age_1'] = pd.cut(df_train['Age'], 3, labels=["bad", "medium", "good"])

# %%
df_train['Age_2'] = labelencoder.fit_transform(df_train['Age_1'])

# %%
df_test['Age_1'] = pd.cut(df_test['Age'], 3, labels=["bad", "medium", "good"])

# %%
df_test['Age_2'] = labelencoder.fit_transform(df_test['Age_1'])

# %%
del df_train['Age_1']

# %%
del df_test['Age_1']

# %%
del df_train['Age']

# %%
del df_test['Age']

# %%
del df_train['Training_score']

# %%
del df_test['Training_score']

# %%
del df_train['Training_score_average']

# %%
del df_test['Training_score_average']

# %%
df_train['Years_of_recruitment'] = pd.cut(df_train['Years_of_recruitment'], 3, labels=["bad", "medium", "good"])
df_test['Years_of_recruitment'] = pd.cut(df_test['Years_of_recruitment'], 3, labels=["bad", "medium", "good"])

# %%
df_train['Yearss_of_recruitment'] =  labelencoder.fit_transform(df_train['Years_of_recruitment'])
df_test['Yearss_of_recruitment'] =  labelencoder.fit_transform(df_test['Years_of_recruitment'])

# %%
del df_test['Years_of_recruitment']
del df_train['Years_of_recruitment']

# %%
 Year_of_recruitment=  pd.get_dummies(df_train['Yearss_of_recruitment'])
Year_of_recruitment=  pd.get_dummies(df_test['Yearss_of_recruitment'])

# %%
df_train['Division'] = pd.cut(df_train['Division'], 3, labels=["bad", "medium", "good"])
df_test['Division'] = pd.cut(df_test['Division'], 3, labels=["bad", "medium", "good"])

# %%
df_train['Division'] =  labelencoder.fit_transform(df_train['Division'])
df_test['Division'] =  labelencoder.fit_transform(df_test['Division'])

# %%
df_train
# Out:
#         EmployeeNo  Division  Qualification  Gender  Channel_of_Recruitment  \
# 0      YAK/S/00001         0              1       0                       1
# 1      YAK/S/00002         0              0       1                       0
# 2      YAK/S/00003         0              0       1                       1
# 3      YAK/S/00004         0              0       1                       0
# 4      YAK/S/00006         2              0       1                       1
# ...            ...       ...            ...     ...                     ...
# 38306  YAK/S/54801         2              0       1                       0
# 38307  YAK/S/54802         2              0       0                       1
# 38308  YAK/S/54805         0              1       0                       0
# 38309  YAK/S/54806         2              0       1                       0
# 38311  YAK/S/54808         2              0       1                       0
#
# ...

# %%
x_test = df_test.drop(['EmployeeNo'], axis=1)

# %%
# Spliting target variable and independent variables
X = df_train.drop(['Promoted_or_Not','EmployeeNo'], axis = 1)
y = df_train['Promoted_or_Not']

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Value of y intercept
logreg.intercept_
# Out:
# array([-3.86001438])

# %%
#Import knearest neighbors Classifier model
from sklearn.neighbors import KNeighborsClassifier

#Create KNN Classifier
knn = KNeighborsClassifier(n_neighbors=4)

#Train the model using the training sets
knn.fit(X_train, y_train)

#Predict the response for test dataset
y_predict = knn.predict(X_train)
y_pred = knn.predict(X_test)

# %%
    #Compute accuracy on the training set
train_accuracy = knn.score(X_train, y_train)

    #Compute accuracy on the testing set
test_accuracy = knn.score(X_test, y_test)


neighbors = np.arange(0, 8)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))

# %%
# Generate plot
plt.title('k-NN: Varying Number of Neighbors')
plt.plot(neighbors, test_accuracy, label = 'Testing Accuracy')
plt.plot(neighbors, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()

# %%
from sklearn import metrics
print("KNN model accuracy(in train):", metrics.accuracy_score(y_train, y_predict)*100)
print("KNN model accuracy(in test):", metrics.accuracy_score(y_test, y_pred)*100)
# Out:
# KNN model accuracy(in train): 91.98878940088811
# KNN model accuracy(in test): 90.74134730865815

# %%
#Import svm model
from sklearn import svm

#Create a svm Classifier
svboy = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
svboy.fit(X_train, y_train)

#Predict the response for test dataset
y_predictor = svboy.predict(X_test)

# %%
from xgboost import XGBClassifier

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)


model = XGBClassifier(silent=False, 
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.4,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=4,
                      base_estimator = None,
                      gamma=10)
model.fit(X_train, y_train)

# make predictions for test set
y_preding = model.predict(X_test)
# Out:
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=4
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 2 pruned nodes, max_depth=1
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 12 pruned nodes, max_depth=1
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=4
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [22:03:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=4
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
random=RandomForestClassifier(n_estimators=2200)

#Train the model using the training sets y_pred=clf.predict(X_test)
random.fit(X_train,y_train)
y_predictioning=random.predict(X_test)

# %%
from sklearn.naive_bayes import GaussianNB 

gnb = GaussianNB() 
gnb.fit(X_train, y_train) 

# making predictions on the testing set 
y_predro = gnb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
# comparing actual response values (y_test) with predicted response values (y_pred) 
from sklearn import metrics 
print("Logistics reg model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
print("KNN model accuracy(in %):", metrics.accuracy_score(y_test, y_predict)*100)
print("SVC model accuracy(in %):", metrics.accuracy_score(y_test, y_predictor)*100)
print("xgb model accuracy(in %):", metrics.accuracy_score(y_test, y_preding)*100)
print("random forest model accuracy(in %):", metrics.accuracy_score(y_test, y_predictioning)*100)
print("Naiive baye accuracy(in %):", metrics.accuracy_score(y_test, y_predro)*100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-11881b8069a7> in <module>()
#       1 # comparing actual response values (y_test) with predicted response values (y_pred)
#       2 from sklearn import metrics
# ----> 3 print("Logistics reg model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
#       4 print("KNN model accuracy(in %):", metrics.accuracy_score(y_test, y_predict)*100)
#       5 print("SVC model accuracy(in %):", metrics.accuracy_score(y_test, y_predictor)*100)
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
# ...

# %%
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor
# explicitly require this experimental feature
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
# now you can import normally from ensemble
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
his = HistGradientBoostingClassifier()
his.fit(X_train, y_train)
y_predictions=his.predict(x_test)
his.score(X_train, y_train)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada= AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
        learning_rate=1, n_estimators=100, random_state=0)
ada.fit(X_train, y_train)  
ada.score(X_train, y_train)

# %%
from sklearn import linear_model

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
submission = pd.DataFrame({"EmployeeNo":df_test["EmployeeNo"],
                           "Promoted_or_Not":y_predictions})
submission.to_csv("submit7b.csv", index=False)

# %%
submission.head()
